# %% [markdown]
# # Import needed libraries

# %%
pip install pyarabic
# Out:
# Requirement already satisfied: pyarabic in /usr/local/lib/python3.10/dist-packages (0.6.15)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from pyarabic) (1.16.0)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re  # Regular expression library for pattern matching and text manipulation
import pandas as pd  # Library for data manipulation and analysis, using DataFrames
import xml.etree.ElementTree as ET  # Library for parsing and working with XML data
import pyarabic.araby as araby  # Library for Arabic text processing, including normalization and tokenization
import numbers  # Library for numeric operations and handling
import nltk  # Natural Language Toolkit library for natural language processing tasks
from nltk.corpus import stopwords  # NLTK's corpus module for accessing stop words in various languages

# %% [markdown]
# # Text Processing Resources

# %%
# Special characters to be handled in text processing
special = ['~','!','@','#','$','%','^','&','*','(',')','_','-','+','=','{','}','?','>','<',':']

# List of common stop words in Arabic, used for text preprocessing
stop_words = ['من',
 'في',
 'على',
 'و',
 'فى',
 'يا',
 'عن',
 'مع',
 'ان',
 'هو',
 'علي',
 'ما',
 'اللي',
 'كل',
 'بعد',
 'ده',
 'اليوم',
 'أن',
 'يوم',
 'انا',
 'إلى',
 'كان',
 'ايه',
 'اللى',
 'الى',
 'دي',
 'بين',
 'انت',
 'أنا',
 'حتى',
 'لما',
 'فيه',
 'هذا',
 'واحد',
 'احنا',
 'اي',
 'كده',
 'إن',
 'او',
 'أو',
 'عليه',
 'ف',
 'دى',
 'مين',
 'الي',
 'كانت',
 'أمام',
 'زي',
 'يكون',
 'خلال',
 'ع',
 'كنت',
 'هي',
 'فيها',
 'عند',
 'التي',
 'الذي',
 'قال',
 'هذه',
 'قد',
 'انه',
 'ريتويت',
 'بعض',
 'أول',
 'ايه',
 'الان',
 'أي',
 'منذ',
 'عليها',
 'له',
 'ال',
 'تم',
 'ب',
 'دة',
 'عليك',
 'اى',
 'كلها',
 'اللتى',
 'هى',
 'دا',
 'انك',
 'وهو',
 'ومن',
 'منك',
 'نحن',
 'زى',
 'أنت',
 'انهم',
 'معانا',
 'حتي',
 'وانا',
 'عنه',
 'إلي',
 'ونحن',
 'وانت',
 'منكم',
 'وان',
 'معاهم',
 'معايا',
 'وأنا',
 'عنها',
 'إنه',
 'اني',
 'معك',
 'اننا',
 'فيهم',
 'د',
 'انتا',
 'عنك',
 'وهى',
 'معا',
 'آن',
 'انتي',
 'وأنت',
 'وإن',
 'ومع',
 'وعن',
 'معاكم',
 'معاكو',
 'معاها',
 'وعليه',
 'وانتم',
 'وانتي',
 '¿',
 '|']

stop_words = stopwords.words("arabic")
# Stemming Part: Prefixes, Articles, and Suffixes for Arabic word stemming

# List of articles in Arabic, used in stemming
articles = ['بال','فال','وال','كال','ولل','ال','ال', 'لي',' ا',' فبال','لبال','وبال']

# Lists of common prefixes in Arabic, used in stemming
p=['مست','فلىست' ,'الاست','افاست','اتست','اىست','فاست','ءاست'
    ,'انهم','ءانى','والم','باست','گمست','والا' ,'ولت','فلى',
   'فلن','فلل','فهو','فهم','فال','ىست','تست','است','فهى',
   'سيا','فلا','ءست','بمس','لىت','ل','ب','و','ف','س','ي',
   'ت','ون','فى','فب','فت','لي','فن','لل','وب','فا','ول',
   'وو','اف','ات','وى','وت','اا','ال','ست','سى','يس','يت',
   'گت','ىى','تت', 'اى' ]

p2_dash=['لا']

# Lists of common suffixes in Arabic, used in stemming
s1=['ت','گ','ي','ه']
s2=['وا','ون','هن','ان','وك','اك','اه','ها','لل','هم','كن','ات','ىن']
s3=['تنا','نها','تان','ناگ','ونه','ناه','هما','وعا','نهم','وهم','ونى','وعن','تها','تهم','نگم','هات','هان','تان','تهن','وگم','ونه','ونگ','انگ']
s4=['موهم','موهن','ناگم','نوهن','ونهم','ناهم','ونگم','توهم','اتها','اتهم','يانه','اءهم']
s5=['گموها','ناهما','ناگمو']

# %% [markdown]
# # Read Data
# Data can be found here: https://drive.google.com/drive/folders/1lBsOoWkbNmCB5hRUFPThAHKYniURz2it?usp=sharing

# %%
def read_doc(doc):
    """
    Read a text document and split it into words.

    Parameters:
    - doc (str): The path to the text document.

    Returns:
    - words (list): A list of words extracted from the document.
    """
    # Open the file and read all lines
    with open(doc, encoding="utf8") as f:
        lines = f.readlines()

    words = []  # Initialize an empty list to store words

    # Split each line into words and add them to the words list
    for line in lines:
        words.extend(line.split())

    return words

# %%
def read_csv(csv):
    """
    Read a CSV file and extract data from the first two columns.

    Parameters:
    - csv (str): The path to the CSV file.

    Returns:
    - column1 (pd.Series): The data from the first column.
    - column2 (pd.Series): The data from the second column.
    """
    # Read the CSV file into a DataFrame
    data = pd.read_csv(csv)

    # Extract data from the first two columns into separate Series
    column1 = data.iloc[:, 0]  # First column
    column2 = data.iloc[:, 1]  # Second column

    return column1, column2

# %%
def read_xml(xml):
    """
    Read an XML file and extract data from specific elements.

    Parameters:
    - xml (str): The path to the XML file.

    Returns:
    - words (list): A list of words extracted from the XML.
    - labels (list): A list of labels extracted from the XML.
    """
    words = []  # List to store words
    labels = []  # List to store labels

    # Parse the XML file into an ElementTree object
    tree = ET.parse(xml)

    # Get the root element of the XML tree
    root = tree.getroot()

    # Iterate through 'analysis' elements in the XML tree
    for child in root.iter('analysis'):
        # Check if the 'a_id' attribute of the element is "1"
        if child.get('a_id') == "1":
            # Extract 'vowled' and 'stem' attributes and add them to the lists
            words.append(child.get('vowled'))
            labels.append(child.get('stem'))

    return words, labels

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
words,labels=read_xml("/content/drive/MyDrive/Arabic_Stemmer_Data/0450AbuHasanMawardi.HawiKabir-sample.xml")

###prepare Arabic document###########
Arabic_doc=[]
Arabic_doc=Arabic_doc+read_doc("/content/drive/MyDrive/Arabic_Stemmer_Data/0450AbuHasanMawardi.HawiKabir-sample.txt")+read_doc("/content/drive/MyDrive/Arabic_Stemmer_Data/0460ShaykhTusi.Mabsut-sample.txt")+read_doc("/content/drive/MyDrive/Arabic_Stemmer_Data/0483IbnAhmadSarakhsi.Mabsut-sample.txt")

#####prepare output#####
output=[]
true=0
for i in range(len(words)):
 output.append("")

# %% [markdown]
# # Stemmer

# %%
def normalize(word):
    """
    Normalize an Arabic word by replacing certain characters with their standard forms.

    Parameters:
    - word (str): The word to be normalized.

    Returns:
    - str: The normalized word.
    """
    for x in range(3):
        word = re.sub("أ", "ا", word)  # Replace "أ" with "ا"
        word = re.sub("إ", "ا", word)  # Replace "إ" with "ا"
        word = re.sub("ٱ", "ا", word)  # Replace "ٱ" with "ا"
        word = re.sub("آ", "ا", word)  # Replace "آ" with "ا"
        word = re.sub("ء", "ا", word)  # Replace "ء" with "ا"
        word = re.sub("چ", "ج", word)  # Replace "چ" with "ج"
        word = re.sub("ڤ", "ف", word)  # Replace "ڤ" with "ف"
        word = re.sub("ڥ", "ف", word)  # Replace "ڥ" with "ف"
        word = re.sub("ڢ", "ف", word)  # Replace "ڢ" with "ف"
        #word = re.sub("ة", "ه", word)  # Replace "ة" with "ه" (you might want to uncomment this line)
        word = re.sub("گ", "ك", word)  # Replace "گ" with "ك"
        word = re.sub("پ", "ب", word)  # Replace "پ" with "ب"
        word = re.sub("ڜ", "ش", word)  # Replace "ڜ" with "ش"
        word = re.sub("ژ", "ز", word)  # Replace "ژ" with "ز"
        word = re.sub("ؤ", "و", word)  # Replace "ؤ" with "و"
        word = re.sub("ژ", "ز", word)  # Replace "ژ" with "ز"
    return word

# %%
def Def_articles_removal(word):
    """
    Remove articles from the beginning of an Arabic word.

    Parameters:
    - word (str): The word from which articles need to be removed.

    Returns:
    - str: The word with articles removed.
    """
    # Check if the first character of the word is an article
    if word[0:1] in articles:
        word = word.replace(word[0:1], "")  # Remove the article from the word

    # Check if the first two characters of the word form an article
    if word[0:2] in articles:
        word = word.replace(word[0:2], "")  # Remove the article from the word

    # Check if the first three characters of the word form an article
    if word[0:3] in articles:
        word = word.replace(word[0:3], "")  # Remove the article from the word

    return word

# %%
def suffix_removal(word):
    """
    Remove common suffixes from an Arabic word.

    Parameters:
    - word (str): The word from which suffixes need to be removed.

    Returns:
    - str: The word with suffixes removed.
    """
    for x in range(len(word)):
        # Check for longer suffixes first
        if len(word) >= 8:
            if word[-5:] in s5:
                word = word.replace(word[-5:], "")
                return word
        if len(word) >= 7:
            if word[-4:] in s4:
                word = word.replace(word[-4:], "")
                return word
        if len(word) >= 6:
            if word[-3:] in s3:
                word = word.replace(word[-3:], "")
                return word
        if len(word) >= 5:
            if word[-2:] in s2:
                word = word.replace(word[-2:], "")
                return word
        if len(word) >= 4:
            if word[-1:] in s1:
                word = word.replace(word[-1:], "")
                return word
    return word

# %%
def remove_prefixes(word):
    """
    Remove common prefixes from an Arabic word.

    Parameters:
    - word (str): The word from which prefixes need to be removed.

    Returns:
    - str: The word with prefixes removed.
    """
    if len(word) >= 5:
        # Check for longer prefixes first
        if word[0:3] in p:
            word = word.replace(word[0:3], "")
    if len(word) >= 4:
        if word[0:2] in p:
            word = word.replace(word[0:2], "")
        if word[0:2] in p2_dash:
            word = word.replace(word[0:1], "")
        # Handle special cases for prefixes like 'و', 'ب', 'ل', 'ا'
        if word[0] == 'و':
            word = word.replace(word[0:1], "")
        if word[0] == 'ب' or word[0] == 'ل' or word[0] == 'ا':
            if word[1:] in Arabic_doc:
                word = word.replace(word[0:1], "")
    if len(word) >= 3:
        # Handle prefixes like 'ب', 'ل', 'ا', 'و'
        if word[0] == 'ب' or word[0] == 'ل' or word[0] == 'ا' or word[0] == 'و':
            if word[1:] in Arabic_doc:
                word = word.replace(word[0:1], "")
    return word

# %%
#apply normalization on labels, stop words and Arabic_doc
for i in range(len(labels)):
 labels[i] = araby.strip_diacritics(labels[i])
 labels[i] = araby.strip_tatweel(labels[i])
 labels[i]=normalize(labels[i])
for i in range(len(Arabic_doc)):
 Arabic_doc[i] = araby.strip_diacritics(Arabic_doc[i])
 Arabic_doc[i] = araby.strip_tatweel(Arabic_doc[i])
 Arabic_doc[i]=normalize(Arabic_doc[i])

####on words
for i in range(len(words)):
 # remove eltashkeel###
 output[i]=araby.strip_diacritics(words[i])
 # remove tatweel
 output[i] = araby.strip_tatweel(output[i])
 # Normalization
 output[i] = normalize(output[i])


#######stemmer######
for i in range(len(words)):
 # keep numbers, special charachters, stop words and the word “الله“ in output as in input
 if (isinstance(output[i], numbers.Number)) or (output[i] in special) or (output[i] in stop_words) or (
         output[i] == "الله"):
  output[i] = output[i]
 else:
  #Remove Definition articles
  output[i] = Def_articles_removal(output[i])
  # apply Remove Prefixes
  output[i] = remove_prefixes(output[i])
  # apply Remove suffixes
  output[i] = suffix_removal(output[i])
  print("word: ",words[i],"    ","output: ",output[i],"    ","stem: ",labels[i])
  if output[i]==labels[i]:
    true=true+1
# Out:
# word:  بِسُمِّ      output:  بسم      stem:  سم
# word:  الرَّحِيمُ      output:  رحيم      stem:  رحيم
# word:  اللَّهْمُ      output:  لهم      stem:  لهم
# word:  يُسْرُ      output:  يسر      stem:  يسر
# word:  وَأَعَنَّ      output:  عن      stem:  اعن
# word:  كَرِيمِ      output:  كريم      stem:  ريم
# word:  الْحَمْدُ      output:  حمد      stem:  حمد
# word:  لله      output:  ه      stem:  الله
# word:  أَوَضَحُ      output:  اوضح      stem:  وضح
# word:  دَيْنُهُ      output:  دين      stem:  دين
# word:  عَلِيُّنَا      output:  علينا      stem:  علي
# word:  بِتَنْزِيلِ      output:  بتنزيل      stem:  تنزيل
# word:  كُتَّابُهُ      output:  كتاب      stem:  كتاب
# word:  وَأَمَدُنَا      output:  امدنا      stem:  امد
# word:  بِسُنَّةِ      output:  بسنة      stem:  سنة
# word:  رَسُولُهُ      output:  رسول      stem:  رسول
# word:  تَمَهُّدُ      output:  تمهد      stem:  تمهد
# word:  الْأَمَةُ      output:  امة      stem:  امة
# word:  أُصُول      output:  اصول      stem:  اصول
# word:  بِنَصِّ      output:  نص      stem:  نص
# word:  وَمَعْقُولُ      output:  معقل      stem:  معقول
# word:  تَوَصَّلُوا      output:  توصل      stem:  توصلوا
# word:  إِلَى      output:  ى      stem:  الى
# word:  الْحَادِثُ      output:  حادث      stem:  حادث
# word:  النَّازِلُ      output:  نازل      stem:  نازل
# word:  وَإدْرَاك      output:  ادر      stem:  ادراك
# word:  الْغَامِضُ      output:  غامض      stem:  غامض
# word:  الْمَشْكَلُ      output:  مشكل      stem:  مشكل
# word:  فلله      output:  فلل      stem:  الله
# word:  الْحَمْدُ      output:  حمد      stem:  حمد
# word:  أَنَعَمُ      output:  انعم      stem:  نعم
# word:  هِدَايَتُهُ      output:  دايت      stem:  هداية
# word:  وَصَلَوَاتُهُ      output:  صلات      stem:  صلوات
# word:  رَسُولُهُ      output:  رسول      stem:  رسول
# word:  مُحَمَّد      output:  محمد      stem:  محمد
# word:  وَآلُهُ      output:  ه      stem:  ال
# word:  وَأَصْحَابُهُ      output:  اصحاب      stem:  اصحاب
# word:  بُنُّ      output:  بن      stem:  بن
# word:  إِدْرِيس      output:  ادريس      stem:  ادريس
# word:  الشَّافِعَيْ      output:  شافع      stem:  شافعي
# word:  رَضِيُّ      output:  رضي      stem:  رضي
# word:  عَنُّهُ      output:  عنه      stem:  عن
# word:  تَوَسُّطُ      output:  توسط      stem:  توسط
# word:  بِحُجَّتِي      output:  بحجت      stem:  حجة
# word:  النُّصُوصُ      output:  نصوص      stem:  نصوص
# word:  الْمَنْقُولَةُ      output:  منقولة      stem:  منقولة
# word:  وَالْمُعَانِي      output:  معان      stem:  معاني
# word:  الْمَعْقُولَةُ      output:  معقولة      stem:  معقولة
# word:  يُصِرُّهُ      output:  يصر      stem:  يصر
# word:  بِالْمِيلِ      output:  ميل      stem:  ميل
# word:  إِلَى      output:  ى      stem:  الى
# word:  أَحَدُهُمَا      output:  احد      stem:  احد
# word:  مَقْصَرًا      output:  مقصرا      stem:  مقصرا
# word:  أَحَقُّ      output:  احق      stem:  حق
# word:  وَبِطْرِيقُهُ      output:  طريق      stem:  بطريق
# word:  أَوَثُقَ      output:  اوثق      stem:  وثق
# word:  وَلَمًّا      output:  ما      stem:  لما
# word:  أَصْحَابُ      output:  اصحاب      stem:  اصحاب
# word:  الشَّافِعَيْ      output:  شافع      stem:  شافعي
# word:  رَضِيُّ      output:  رضي      stem:  رضي
# word:  عَنُّهُ      output:  عنه      stem:  عن
# word:  اقْتَصَرُوا      output:  اقتصر      stem:  اقتصروا
# word:  مُخْتَصَرُ      output:  مختصر      stem:  مختصر
# word:  إِبْراهِيم      output:  ابراهيم      stem:  ابراهيم
# word:  بُنُّ      output:  بن      stem:  بن
# word:  إِسْماعِيل      output:  اسماعيل      stem:  اسماعيل
# word:  يَحْيَى      output:  يحيى      stem:  يحيى
# word:  الْمُزْنَيْ      output:  مزن      stem:  مزني
# word:  رَحِمُهُ      output:  رحم      stem:  رحم
# word:  لَانْتِشَارُ      output:  انتشار      stem:  انتشار
# word:  الْكُتُبُ      output:  كتب      stem:  كتب
# word:  الْمَبْسُوطَةُ      output:  مبسوطة      stem:  مبسوطة
# word:  فَهْمُ      output:  فهم      stem:  فهم
# word:  الْمُتَعَلَّمُ      output:  متعلم      stem:  متعلم
# word:  وَاسْتِطَالَةُ      output:  استطالة      stem:  استطالة
# word:  مُرَاجَعَتُهَا      output:  مراجع      stem:  مراجعة
# word:  الْعَالَمُ      output:  عم      stem:  عالم
# word:  جَعِلُوا      output:  جعل      stem:  جعلوا
# word:  الْمُخْتَصَرُ      output:  مختصر      stem:  مختصر
# word:  أَصَلَاُ      output:  اصلا      stem:  صلا
# word:  يُمَكِّنُهُمْ      output:  يمك      stem:  يمكن
# word:  تَقْرِيبُهُ      output:  تقريب      stem:  تقريب
# word:  الْمُبْتَدِئُ      output:  مبتدئ      stem:  مبتدئ
# word:  لَلْمُنْتَهِي      output:  منته      stem:  منتهي
# word:  وَجُبُّ      output:  وجب      stem:  جب
# word:  صَرْفُ      output:  صرف      stem:  صرف
# word:  الْعَنَايَةُ      output:  عناية      stem:  عناية
# word:  إلِيُّهُ      output:  يه      stem:  الي
# word:  وَإِيقَاعُ      output:  ايقاع      stem:  ايقاع
# word:  الْاهْتِمَامُ      output:  اهتمام      stem:  اهتمام
# word:  وَلَمًّا      output:  ما      stem:  لما
# word:  مُخْتَصَرُ      output:  مختصر      stem:  مختصر
# word:  الْمُزْنَيْ      output:  مزن      stem:  مزني
# word:  بِهَذِّهِ      output:  هذه      stem:  هذ
# word:  الْحَالُ      output:  ح      stem:  حال
# word:  مَذْهَبُ      output:  مذهب      stem:  مذهب
# word:  الشَّافِعَيْ      output:  شافع      stem:  شافعي
# word:  لَزْمُ      output:  لزم      stem:  لزم
# word:  اسْتِيعَابُ      output:  يعاب      stem:  استيعاب
# word:  الْمَذْهَبُ      output:  مذهب      stem:  مذهب
# word:  شَرْحُهُ      output:  شرح      stem:  شرح
# word:  وَاسْتِيفَاءُ      output:  استيفاا      stem:  استيفاا
# word:  اخْتِلَافُ      output:  اختلاف      stem:  اختلاف
# word:  الْفُقَهَاءُ      output:  فقهاا      stem:  فقهاا
# word:  الْمَغْلَقُ      output:  مغلق      stem:  مغلق
# word:  وَإِنَّ      output:  ان      stem:  ان
# word:  خُرُوجًا      output:  خروجا      stem:  خروجا
# word:  الشَّرْحُ      output:  شرح      stem:  شرح
# word:  يَقْتَضِي      output:  قتض      stem:  يقتضي
# word:  الْاقْتِصَارُ      output:  اقتصار      stem:  اقتصار
# word:  إِبَانَةُ      output:  ابانة      stem:  ابانة
# word:  الْمَشْرُوحُ      output:  مشروح      stem:  مشروح
# word:  لَيَصِحُّ      output:  صح      stem:  يصح
# word:  الْاكْتِفَاءُ      output:  اكتفاا      stem:  اكتفاا
# word:  وَالْاسْتِغْنَاءُ      output:  غناا      stem:  استغناا
# word:  غَيْرُهُ      output:  غير      stem:  غير
# word:  وَقَدُّ      output:  قد      stem:  قد
# word:  اعْتَمَدَتْ      output:  اعمد      stem:  اعتمدت
# word:  بِكُتَّابِي      output:  بكتاب      stem:  كتاب
# word:  شَرْحُهُ      output:  شرح      stem:  شرح
# word:  أَعَدْلُ      output:  اعدل      stem:  عدل
# word:  وَتَرْجَمَتُهُ      output:  رجمت      stem:  ترجمة
# word:  الْحَاوِي      output:  حاو      stem:  حاوي
# word:  رَجَاء      output:  رجاا      stem:  رجاا
# word:  أَنُّ      output:  ان      stem:  ان
# word:  يُكْوُنَّ      output:  يكون      stem:  يكون
# word:  حَاوِيًا      output:  حاويا      stem:  حاويا
# word:  أَوَجُبُّهُ      output:  اوجب      stem:  جب
# word:  بِقَدْرِ      output:  بقدر      stem:  قدر
# word:  الْحَالُ      output:  ح      stem:  حال
# word:  الْاسْتِيفَاءُ      output:  يفاا      stem:  استيفاا
# word:  وَالْاسْتِيعَابُ      output:  يعاب      stem:  استيعاب
# word:  أَوَضَحُ      output:  اوضح      stem:  وضح
# word:  تَقْدِيمُ      output:  تقديم      stem:  تقديم
# word:  وَأَصَحَّ      output:  اصح      stem:  اصح
# word:  تَرْتِيبُ      output:  ترتيب      stem:  ترتيب
# word:  وَأَسْهَلَ      output:  سهل      stem:  اسهل
# word:  مَأْخَذُ      output:  ماخذ      stem:  ماخذ
# word:  فُصُولُ      output:  فصول      stem:  فصول
# word:  وَأَنَّا      output:  انا      stem:  انا
# word:  أَسْأَلَ      output:  اسال      stem:  اسال
# word:  أَكَرْمُ      output:  اكرم      stem:  كرم
# word:  مَسْؤُولُ      output:  مسوول      stem:  مسوول
# word:  أَنُّ      output:  ان      stem:  ان
# word:  يَجْعَلُ      output:  يجعل      stem:  يجعل
# word:  التَّوْفِيقُ      output:  توفيق      stem:  توفيق
# word:  مَادَّةُ      output:  مادة      stem:  مادة
# word:  وَالْمَعُونَةُ      output:  معونة      stem:  معونة
# word:  هِدَايَة      output:  هداية      stem:  هداية
# word:  بِطَوْلِهِ      output:  بطول      stem:  طول
# word:  وَمُشَيِّئَتُهُ      output:  مشيئت      stem:  مشيئة
# word:  قَالُ      output:  قال      stem:  قال
# word:  إِبْراهِيم      output:  ابراهيم      stem:  ابراهيم
# word:  بُنُّ      output:  بن      stem:  بن
# word:  إِسْماعِيل      output:  اسماعيل      stem:  اسماعيل
# word:  يَحْيَى      output:  يحيى      stem:  يحيى
# word:  الْمُزْنَيْ      output:  مزن      stem:  مزني
# word:  اخْتَصَرَتْ      output:  اخصر      stem:  اختصرت
# word:  الشَّافِعَيْ      output:  شافع      stem:  شافعي
# word:  مُعَنَّى      output:  معنى      stem:  معنى
# word:  قَوْلُهُ      output:  قول      stem:  قول
# word:  لَأَقْرَبُهُ      output:  اقرب      stem:  اقرب
# word:  أَرَادُّهُ      output:  اراد      stem:  راد
# word:  نَهْيُهُ      output:  ني      stem:  نهي
# word:  تَقْلِيدُهُ      output:  تقليد      stem:  تقليد
# word:  وَتَقْلِيدُ      output:  قليد      stem:  تقليد
# word:  غَيْرُهُ      output:  غير      stem:  غير
# word:  لَيُنَظِّرُ      output:  نظر      stem:  ينظر
# word:  لَدَيْنُهُ      output:  دين      stem:  دين
# word:  وَيَحْتَاطُ      output:  يحتاط      stem:  يحتاط
# word:  لَنَفَسُهُ      output:  نفس      stem:  نفس
# word:  وبالله      output:  ه      stem:  الله
# word:  التَّوْفِيقُ      output:  توفيق      stem:  توفيق
# word:  وَقَالُ      output:  قال      stem:  قال
# word:  ابْتَدَأَ      output:  ابتدا      stem:  ابتدا
# word:  الْمُزْنَيْ      output:  مزن      stem:  مزني
# word:  بِهَذِّهِ      output:  هذه      stem:  هذ
# word:  التَّرْجَمَةُ      output:  ترجمة      stem:  ترجمة
# word:  كُتَّابُهُ      output:  كتاب      stem:  كتاب
# word:  فَاعْتَرَضَ      output:  عترض      stem:  اعترض
# word:  حَسَّادُ      output:  حساد      stem:  حساد
# word:  الْفَضْلُ      output:  فضل      stem:  فضل
# word:  أَغَرَاهُمْ      output:  اغرا      stem:  غرا
# word:  التَّقَدُّمُ      output:  تقدم      stem:  تقدم
# word:  بِالْمُنَازَعَةِ      output:  منازعة      stem:  منازعة
# word:  وَبَعْثُهُمْ      output:  عثهم      stem:  بعث
# word:  الْاشْتِهَارُ      output:  اشتهار      stem:  اشتهار
# word:  الْمَذَمَّةُ      output:  مذمة      stem:  مذمة
# word:  وَكَّانُ      output:  كان      stem:  وكان
# word:  اعْتَرَضَ      output:  اعترض      stem:  اعترض
# word:  الْمُغَرِّبَيْ      output:  مغرب      stem:  مغربي
# word:  الْقَهْيُ      output:  قهي      stem:  قهي
# word:  وَأَبُو      output:  ب      stem:  ابو
# word:  طَالِب      output:  طالب      stem:  طالب
# word:  الْكَاتِبُ      output:  كاتب      stem:  كاتب
# word:  تَعَقُّبُهُمْ      output:  تعقب      stem:  تعقب
# word:  اِبْن      output:  بن      stem:  ابن
# word:  داوُد      output:  داود      stem:  داود
# word:  فَكَّانِ      output:  فكان      stem:  فكان
# word:  اعْتِرَاضُهُمْ      output:  اعتراض      stem:  اعتراض
# word:  وَجَوُّهُ      output:  جه      stem:  جو
# word:  فَأَوْلُ      output:  ل      stem:  اول
# word:  وَجَوُّهُ      output:  جه      stem:  جو
# word:  اعْتِرَاضُهُمْ      output:  اعتراض      stem:  اعتراض
# word:  أَنُّ      output:  ان      stem:  ان
# word:  قَالُّوا      output:  قال      stem:  قالوا
# word:  يَحْمَدُ      output:  يحمد      stem:  يحمد
# word:  تَعَالَى      output:  تعالى      stem:  تعالى
# word:  تَبَرُّكًا      output:  تبركا      stem:  تبركا
# word:  بِذِكْرِهِ      output:  ذكر      stem:  ذكر
# word:  وَاقْتِدَاءُ      output:  اقتداا      stem:  اقتداا
# word:  بِغَيْرِهِ      output:  غير      stem:  غير
# word:  وَاتِّبَاعًا      output:  اتباعا      stem:  اتباعا
# word:  رَوَّاهُ      output:  روا      stem:  رواه
# word:  قُرَّة      output:  قرة      stem:  قرة
# word:  بُنُّ      output:  بن      stem:  بن
# word:  عَبْدُ      output:  عبد      stem:  عبد
# word:  الزَّهَْرِيُّ      output:  زهر      stem:  زهري
# word:  أبِّي      output:  ابي      stem:  اب
# word:  سَلْمَة      output:  سلمة      stem:  سلمة
# word:  أَنُّ      output:  ان      stem:  ان
# word:  رَسُولُ      output:  رسول      stem:  رسول
# word:  قَالُ      output:  قال      stem:  قال
# word:  أَمَّرُ      output:  امر      stem:  امر
# word:  بَالُ      output:        stem:  بال
# word:  يَبْدَأُ      output:  يبدا      stem:  يبدا
# word:  بِحَمَدِ      output:  حمد      stem:  حمد
# word:  فَهُو      output:  فهو      stem:  هو
# word:  أَبْتَرُ      output:  ابتر      stem:  ابتر
# word:  فَالْجَوَابُ      output:  جواب      stem:  جواب
# word:  عَنُّهُ      output:  عنه      stem:  عن
# word:  أَوَجْهُ      output:  وجه      stem:  وجه
# word:  أَحَدُهَا      output:  احد      stem:  احد
# word:  أَنُّ      output:  ان      stem:  ان
# word:  يَقْلَبُ      output:  يقلب      stem:  يقلب
# word:  الْاعْتِرَاضُ      output:  اعتراض      stem:  اعتراض
# word:  عَلِيُّهُمْ      output:  علي      stem:  علي
# word:  وَيَسْتَعْمِلُ      output:  يستعمل      stem:  يستعمل
# word:  دَلِيلُ      output:  دليل      stem:  دليل
# word:  الْخَبَرُ      output:  خبر      stem:  خبر
# word:  سُؤَالُهُمْ      output:  سوال      stem:  سوال
# word:  فَيُقَالُّ      output:  فيقال      stem:  يقال
# word:  إِنَّ      output:  ان      stem:  ان
# word:  سُؤَالُكُمْ      output:  سوالكم      stem:  سوال
# word:  بَالُ      output:        stem:  بال
# word:  فَهَلاَ      output:  فهلا      stem:  هلا
# word:  قَدُمْتُمْ      output:  قدمتم      stem:  قدمتم
# word:  حَمْد      output:  حمد      stem:  حمد
# word:  إلَاُ      output:  ا      stem:  الا
# word:  أَنُّ      output:  ان      stem:  ان
# word:  يُكْوُنَّ      output:  يكون      stem:  يكون
# word:  بَالُ      output:        stem:  بال
# word:  نَعُولُ      output:  نعول      stem:  نعول
# word:  وَكَلُّ      output:  كل      stem:  كل
# word:  سُؤَالُ      output:  سوال      stem:  سوال
# word:  سَائِلُهُ      output:  سائل      stem:  سائل
# word:  مَطْرَحًا      output:  مطرحا      stem:  مطرحا
# word:  وَالْجَوَابُ      output:  جواب      stem:  جواب
# word:  الثَّانِي      output:  ثان      stem:  ثاني
# word:  أَنُّ      output:  ان      stem:  ان
# word:  حَمْد      output:  حمد      stem:  حمد
# word:  يُكْوُنَّ      output:  يكون      stem:  يكون
# word:  خُطًّا      output:  خطا      stem:  خطا
# word:  وَتَّارَةُ      output:  ارة      stem:  وتارة
# word:  لَفْظًا      output:  لفظا      stem:  لفظا
# word:  أَشِبْهُ      output:  اشب      stem:  شبه
# word:  الْأَمَرَيْنِ      output:  امرين      stem:  امرين
# word:  بِظَاهِرِ      output:  بظاهر      stem:  ظاهر
# word:  الْأَمَّرُ      output:  امر      stem:  امر
# word:  وَالْمُزْنَيْ      output:  مزن      stem:  مزني
# word:  حَمْد      output:  حمد      stem:  حمد
# word:  خُطًّا      output:  خطا      stem:  خطا
# word:  وَقَدُّ      output:  قد      stem:  قد
# word:  ذِكْرُهُ      output:  ذكر      stem:  ذكر
# word:  لَفْظًا      output:  لفظا      stem:  لفظا
# word:  رَوِيُّ      output:  روي      stem:  روي
# word:  أَنْهُ      output:  انه      stem:  انه
# word:  يُصْلِي      output:  صل      stem:  يصلي
# word:  رَكْعَتَيْنِ      output:  ركعتين      stem:  ركعتين
# word:  تَصْنِيفُ      output:  تصنيف      stem:  تصنيف
# word:  بَابُ      output:  باب      stem:  باب
# word:  وَالْجَوَابُ      output:  جواب      stem:  جواب
# word:  الثَّالِثُ      output:  ثث      stem:  ثالث
# word:  أَنُّ      output:  ان      stem:  ان
# word:  الْمُزْنَيْ      output:  مزن      stem:  مزني
# word:  حَمْد      output:  حمد      stem:  حمد
# word:  وَسَمَّى      output:  سمى      stem:  سمى
# word:  وَأَتَّى      output:  اتى      stem:  اتى
# word:  كِتَابَةُ      output:  كتابة      stem:  كتابة
# word:  وَلَفْظًا      output:  فظا      stem:  لفظا
# word:  وَقَالُ      output:  قال      stem:  قال
# word:  الْحَمْدُ      output:  حمد      stem:  حمد
# word:  لله      output:  ه      stem:  الله
# word:  شَرَّيْكَ      output:  شريك      stem:  شري
# word:  وَصَفُّ      output:  وصف      stem:  صف
# word:  وَفَوْقُ      output:  فق      stem:  فوق
# word:  يُصِفُّهُ      output:  يصف      stem:  يصف
# word:  خَلْقُهُ      output:  خلق      stem:  خلق
# word:  كَمِثْلِهِ      output:  كمثل      stem:  مثل
# word:  شَيْءُ      output:  شيا      stem:  شيا
# word:  السَّمِيعُ      output:  سميع      stem:  سميع
# word:  الْبَصِيرُ      output:  بصير      stem:  بصير
# word:  فَحَذَفُ      output:  فحذف      stem:  حذف
# word:  النَّاقِلَيْنِ      output:  ناقلين      stem:  ناقلين
# word:  وَالْجَوَابُ      output:  جواب      stem:  جواب
# word:  الرَّابِعُ      output:  رابع      stem:  رابع
# word:  أَنُّ      output:  ان      stem:  ان
# word:  الْمُرَادُّ      output:  مراد      stem:  مراد
# word:  بِحَمَدِ      output:  حمد      stem:  حمد
# word:  إِنَّمَا      output:  انما      stem:  انما
# word:  ذِكْرُ      output:  ذكر      stem:  ذكر
# word:  لَأَمَرَيْنِ      output:  امرين      stem:  امرين
# word:  أَحَدُهُمَا      output:  احد      stem:  احد
# word:  أَنْهُ      output:  انه      stem:  انه
# word:  رَوِيُّ      output:  روي      stem:  روي
# word:  يَبْدَأُ      output:  يبدا      stem:  يبدا
# word:  بِذِكْرِ      output:  ذكر      stem:  ذكر
# word:  وَالثَّانِي      output:  ثان      stem:  ثاني
# word:  يَقْدَرُ      output:  يقدر      stem:  يقدر
# word:  اسْتِعْمَالُهُ      output:  عمال      stem:  استعمال
# word:  لَأَنُّ      output:  ان      stem:  ان
# word:  التَّحْمِيدُ      output:  تحميد      stem:  تحميد
# word:  إِنَّ      output:  ان      stem:  ان
# word:  قَدْمُ      output:  قدم      stem:  قدم
# word:  التَّسْمِيَةُ      output:  تسمية      stem:  تسمية
# word:  خُولِفَ      output:  خولف      stem:  خولف
# word:  الْعَادَةُ      output:  عادة      stem:  عادة
# word:  وَإِنَّ      output:  ان      stem:  ان
# word:  ذِكْرُ      output:  ذكر      stem:  ذكر
# word:  التَّسْمِيَةُ      output:  تسمية      stem:  تسمية
# word:  يُقِعُّ      output:  يقع      stem:  يقع
# word:  الْبَدَّايَةُ      output:  بداية      stem:  بداية
# word:  فَثَبْتُ      output:  فثب      stem:  ثبت
# word:  بِهَذَيْن      output:  هذين      stem:  هذين
# word:  أَنُّ      output:  ان      stem:  ان
# word:  الْمُرَادُّ      output:  مراد      stem:  مراد
# word:  ذِكْرُ      output:  ذكر      stem:  ذكر
# word:  وَقَدُّ      output:  قد      stem:  قد
# word:  بَدَأَ      output:  بدا      stem:  بدا
# word:  بِذِكْرِ      output:  ذكر      stem:  ذكر
# word:  قَوْلُهُ      output:  قول      stem:  قول
# word:  بِسُمِّ      output:  بسم      stem:  سم
# word:  الرَّحِيمُ      output:  رحيم      stem:  رحيم
# word:  وَالْجَوَابُ      output:  جواب      stem:  جواب
# word:  الْخَامِسُ      output:  خامس      stem:  خامس
# word:  أَنُّ      output:  ان      stem:  ان
# word:  الْأَمَّرُ      output:  امر      stem:  امر
# word:  مَحْمُولُ      output:  محمول      stem:  محمول
# word:  ابْتِدَاءُ      output:  ابتداا      stem:  ابتداا
# word:  الْخُطْبَةُ      output:  خطبة      stem:  خطبة
# word:  غَيْرُهَا      output:  غير      stem:  غير
# word:  زَجْرًا      output:  زجرا      stem:  زجرا
# word:  كَانِتُ      output:  كان      stem:  كانت
# word:  الْجَاهِلِيَّةُ      output:  جاهلية      stem:  جاهلية
# word:  تَقْدِيمُ      output:  تقديم      stem:  تقديم
# word:  الْمَنْثُورُ      output:  منثور      stem:  منثور
# word:  وَالْمَنْظُومُ      output:  منظوم      stem:  منظوم
# word:  وَالْكَلَامُ      output:  كلام      stem:  كلام
# word:  وَإِنَّمَا      output:  انما      stem:  انما
# word:  لَثَلَاثَةُ      output:  ثاثة      stem:  ثلاثة
# word:  أَمَوْرُ      output:  امور      stem:  مور
# word:  أَحَدُهَا      output:  احد      stem:  احد
# word:  رَوِيُّ      output:  روي      stem:  روي
# word:  أَنُّ      output:  ان      stem:  ان
# word:  أَعْرَابِيًّا      output:  اعرابيا      stem:  اعرابيا
# word:  خَطْبُ      output:  خطب      stem:  خطب
# word:  فَتُرْكُ      output:  رك      stem:  ترك
# word:  التَّحْمِيدُ      output:  تحميد      stem:  تحميد
# word:  فَقَالُ      output:  فقال      stem:  قال
# word:  النَّبِيُّ      output:  نبي      stem:  نبي
# word:  أَمَّرُ      output:  امر      stem:  امر
# word:  بَالُ      output:        stem:  بال
# word:  يَبْدَأُ      output:  يبدا      stem:  يبدا
# word:  بِحَمَدِ      output:  حمد      stem:  حمد
# word:  فَهُو      output:  فهو      stem:  هو
# word:  أَبْتَرُ      output:  ابتر      stem:  ابتر
# word:  وَالثَّانِي      output:  ثان      stem:  ثاني
# word:  أَنُّ      output:  ان      stem:  ان
# word:  أَوْلُ      output:  اول      stem:  اول
# word:  نَزَلُ      output:  نزل      stem:  نزل
# word:  كُتَّابُ      output:  كتاب      stem:  كتاب
# word:  عِزّ      output:  عز      stem:  عز
# word:  وَجْلُ      output:  جل      stem:  وجل
# word:  قَوْلُهُ      output:  قول      stem:  قول
# word:  اقْرَأْ      output:  اقرا      stem:  اقرا
# word:  بَاسِم      output:  اسم      stem:  باسم
# word:  رَبُّكَ      output:  ربك      stem:  رب
# word:  خَلْقُ      output:  خلق      stem:  خلق
# word:  الْعَلَقُ      output:  علق      stem:  علق
# word:  وَقَوْلُهُ      output:  قله      stem:  قول
# word:  أَيَّهَا      output:  ايها      stem:  ايها
# word:  الْمَدْثَرُ      output:  مدثر      stem:  مدثر
# word:  وَلَيَسُ      output:  يس      stem:  ليس
# word:  حَمْد      output:  حمد      stem:  حمد
# word:  فَلَمُّ      output:  فلم      stem:  لم
# word:  يَجِزُّ      output:  يجز      stem:  يجز
# word:  أَنُّ      output:  ان      stem:  ان
# word:  يَأْمَرُ      output:  يامر      stem:  يامر
# word:  رَسُولُ      output:  رسول      stem:  رسول
# word:  كُتَّابُ      output:  كتاب      stem:  كتاب
# word:  تَعَالَى      output:  تعالى      stem:  تعالى
# word:  خِلَافُهُ      output:  خلاف      stem:  خلاف
# word:  وَالثَّالِثُ      output:  ثالث      stem:  ثالث
# word:  أَنُّ      output:  ان      stem:  ان
# word:  خَبَرُ      output:  خبر      stem:  خبر
# word:  رَسُولُ      output:  رسول      stem:  رسول
# word:  يُجَوِّزُ      output:  يجوز      stem:  يجوز
# word:  أَنُّ      output:  ان      stem:  ان
# word:  يُكْوُنَّ      output:  يكون      stem:  يكون
# word:  بِخِلَافِ      output:  بخلاف      stem:  خلاف
# word:  مَخْبَرُهُ      output:  مخبر      stem:  مخبر
# word:  فَقَدُّ      output:  فقد      stem:  قد
# word:  قَالُ      output:  قال      stem:  قال
# word:  فَهُو      output:  فهو      stem:  هو
# word:  أَبْتَرُ      output:  ابتر      stem:  ابتر
# word:  وَكُتَّابُ      output:  كتاب      stem:  كتاب
# word:  الْمُزْنَيْ      output:  مزن      stem:  مزني
# word:  أَشَهْرُ      output:  اشهر      stem:  شهر
# word:  كُتَّابُ      output:  كتاب      stem:  كتاب
# word:  صِنْفُ      output:  صنف      stem:  صنف
# word:  وَأَبْدَعُ      output:  ابدع      stem:  ابدع
# word:  مُخْتَصَرُ      output:  مختصر      stem:  مختصر
# word:  أُلُفُ      output:  ف      stem:  الف
# word:  فَعِلْمُ      output:  فعلم      stem:  علم
# word:  بِهَذِّهِ      output:  هذه      stem:  هذ
# word:  الْأُمُورُ      output:  امور      stem:  امور
# word:  أَنْهُ      output:  انه      stem:  انه
# word:  مَحْمُولُ      output:  محمول      stem:  محمول
# word:  الْخَطْبُ      output:  خطب      stem:  خطب
# word:  غَيْرُهَا      output:  غير      stem:  غير
# word:  الْمُصَنِّفَاتُ      output:  مصنف      stem:  مصنفات
# word:  وَالْكُتُبُ      output:  كتب      stem:  كتب
# word:  فَصْلُ      output:  فصل      stem:  فصل
# word:  وَالْاعْتِرَاضُ      output:  اعتراض      stem:  اعتراض
# word:  الثَّانِي      output:  ثان      stem:  ثاني
# word:  إِنَّ      output:  ان      stem:  ان
# word:  قَالُّوا      output:  قال      stem:  قالوا
# word:  قَالُ      output:  قال      stem:  قال
# word:  اخْتَصَرَتْ      output:  اخصر      stem:  اختصرت
# word:  اخْتِصَارُهُ      output:  اختصار      stem:  اختصار
# word:  وَهَذًّا      output:  هذا      stem:  هذا
# word:  كَذْبُ      output:  كذب      stem:  كذب
# word:  وَالْجَوَابُ      output:  جواب      stem:  جواب
# word:  عَنُّهُ      output:  عنه      stem:  عن
# word:  أَوَجْهُ      output:  وجه      stem:  وجه
# word:  أَحَدُهَا      output:  احد      stem:  احد
# word:  أَنْهُ      output:  انه      stem:  انه
# word:  تَرْجَمَ      output:  ترجم      stem:  ترجم
# word:  كُتَّابُهُ      output:  كتاب      stem:  كتاب
# word:  فِرَاغُهُ      output:  فراغ      stem:  فراغ
# word:  وَأَرَادَ      output:  اراد      stem:  اراد
# word:  اخْتَصَرَ      output:  اختصر      stem:  اختصر
# word:  بِالْاخْتِصَارِ      output:  اختصار      stem:  اختصار
# word:  وَالْجَوَابُ      output:  جواب      stem:  جواب
# word:  الثَّانِي      output:  ثان      stem:  ثاني
# word:  أَنْهُ      output:  انه      stem:  انه
# word:  صُورُ      output:  صور      stem:  صور
# word:  الْكُتَّابُ      output:  كتاب      stem:  كتاب
# word:  نَفَسُهُ      output:  نفس      stem:  نفس
# word:  مُخْتَصَرًا      output:  مختصرا      stem:  مختصرا
# word:  أَوِّ      output:  او      stem:  او
# word:  أَشَّارُ      output:  اشار      stem:  اشار
# word:  بِالْاخْتِصَارِ      output:  اختصار      stem:  اختصار
# word:  إِلَى      output:  ى      stem:  الى
# word:  نَفَسُهُ      output:  نفس      stem:  نفس
# word:  مُخْتَصَرًا      output:  مختصرا      stem:  مختصرا
# word:  وَالْجَوَابُ      output:  جواب      stem:  جواب
# word:  الثَّالِثُ      output:  ثث      stem:  ثالث
# word:  أَنْهُ      output:  انه      stem:  انه
# word:  قَالُ      output:  قال      stem:  قال
# word:  اخْتَصَرَتْ      output:  اخصر      stem:  اختصرت
# word:  بِمُعْنَى      output:  معنى      stem:  معنى
# word:  سَأَخْتَصِرُ      output:  ساختصر      stem:  اختصر
# word:  وَالْعَرَبُ      output:  عرب      stem:  عرب
# word:  تَقَوُّلُ      output:  تقول      stem:  تقول
# word:  فَعَلَّتْ      output:  فعل      stem:  علت
# word:  بِمُعْنَى      output:  معنى      stem:  معنى
# word:  سَأَفْعَلُ      output:  سافعل      stem:  افعل
# word:  قَالُ      output:  قال      stem:  قال
# word:  تَعَالَى      output:  تعالى      stem:  تعالى
# word:  أَتَّى      output:  اتى      stem:  اتى
# word:  أَمَّرُ      output:  امر      stem:  امر
# word:  تَسْتَعْجِلُوهُ      output:  عجلو      stem:  تستعجلوا
# word:  النَّحْلُ      output:  نحل      stem:  نحل
# word:  بِمُعْنَى      output:  معنى      stem:  معنى
# word:  سِيأَتِي      output:  تي      stem:  سياة
# word:  أَمَّرُ      output:  امر      stem:  امر
# word:  وَنَادَى      output:  ادى      stem:  نادى
# word:  أَصْحَابُ      output:  اصحاب      stem:  اصحاب
# word:  الْجَنَّةُ      output:  جنة      stem:  جنة
# word:  الْأَعْرَافُ      output:  اعراف      stem:  اعراف
# word:  بِمُعْنَى      output:  معنى      stem:  معنى
# word:  سَيُنَادِي      output:  سناد      stem:  ينادي
# word:  أَصْحَابُ      output:  اصحاب      stem:  اصحاب
# word:  الْجَنَّةُ      output:  جنة      stem:  جنة
# word:  فَصْلُ      output:  فصل      stem:  فصل
# word:  وَالْاعْتِرَاضُ      output:  اعتراض      stem:  اعتراض
# word:  الثَّالِثُ      output:  ثث      stem:  ثالث
# word:  إِنَّ      output:  ان      stem:  ان
# word:  قَالُّوا      output:  قال      stem:  قالوا
# word:  قَالُ      output:  قال      stem:  قال
# word:  اخْتَصَرَتْ      output:  اخصر      stem:  اختصرت
# word:  كَلِمَةُ      output:  كلمة      stem:  كلمة
# word:  مَوْضُوعَةُ      output:  موضوعة      stem:  موضوعة
# word:  اللُّغَةُ      output:  لغة      stem:  لغة
# word:  إشَارَةُ      output:  اشارة      stem:  اشارة
# word:  إِلَى      output:  ى      stem:  الى
# word:  حَاضِرُ      output:  حاضر      stem:  حاضر
# word:  مُعِين      output:  معين      stem:  معين
# word:  أَنُّ      output:  ان      stem:  ان
# word:  غَائِبُ      output:  غائب      stem:  غائب
# word:  وَلَمُّ      output:  لم      stem:  لم
# word:  يَكِنَّ      output:  يكن      stem:  يكن
# word:  يُشِيرُ      output:  يشير      stem:  يشير
# word:  إلِيُّهُ      output:  يه      stem:  الي
# word:  وَهَذًّا      output:  هذا      stem:  هذا
# word:  جُهَّلُ      output:  جهل      stem:  جهل
# word:  بِاللُّغَةِ      output:  لغة      stem:  لغة
# word:  مَوْضُوعُ      output:  موضوع      stem:  موضوع
# word:  الْكَلَامُ      output:  كلام      stem:  كلام
# word:  وَالْجَوَابُ      output:  جواب      stem:  جواب
# word:  عَنُّهُ      output:  عنه      stem:  عن
# word:  أَوَجْهُ      output:  وجه      stem:  وجه
# word:  أَحَدُهَا      output:  احد      stem:  احد
# word:  أَنْهُ      output:  انه      stem:  انه
# word:  تَرْجَمَ      output:  ترجم      stem:  ترجم
# word:  كُتَّابُهُ      output:  كتاب      stem:  كتاب
# word:  الْفِرَاغُ      output:  فراغ      stem:  فراغ
# word:  فَصَارُّ      output:  فصار      stem:  صار
# word:  إشَارَةُ      output:  اشارة      stem:  اشارة
# word:  إِلَى      output:  ى      stem:  الى
# word:  حَاضِرُ      output:  حاضر      stem:  حاضر
# word:  مُعِين      output:  معين      stem:  معين
# word:  وَالثَّانِي      output:  ثان      stem:  ثاني
# word:  أَنْهُ      output:  انه      stem:  انه
# word:  صُورُهُ      output:  صور      stem:  صور
# word:  نَفَسُهُ      output:  نفس      stem:  نفس
# word:  وَأَشَّارُ      output:  اشار      stem:  اشار
# word:  إِلَى      output:  ى      stem:  الى
# word:  يَعْيَنُ      output:  يعين      stem:  يعين
# word:  ضَمِيرُهُ      output:  ضمير      stem:  ضمير
# word:  وَالثَّالِثُ      output:  ثالث      stem:  ثالث
# word:  أَنُّ      output:  ان      stem:  ان
# word:  وَإِنَّ      output:  ان      stem:  ان
# word:  إشَارَةُ      output:  اشارة      stem:  اشارة
# word:  إِلَى      output:  ى      stem:  الى
# word:  حَاضِرُ      output:  حاضر      stem:  حاضر
# word:  مُعِين      output:  معين      stem:  معين
# word:  فَقَدُّ      output:  فقد      stem:  قد
# word:  يَسْتَعْمِلُهُ      output:  تعمل      stem:  يستعمل
# word:  الْعَرَبُ      output:  عرب      stem:  عرب
# word:  إشَارَةُ      output:  اشارة      stem:  اشارة
# word:  إِلَى      output:  ى      stem:  الى
# word:  غَائِبُ      output:  غائب      stem:  غائب
# word:  قَالُ      output:  قال      stem:  قال
# word:  تَعَالَى      output:  تعالى      stem:  تعالى
# word:  يَوْمُ      output:  يوم      stem:  يوم
# word:  الْفَصْلُ      output:  فصل      stem:  فصل
# word:  الْمُرَسِّلَاتُ      output:  مرسل      stem:  مرسلات
# word:  يَوْمُ      output:  يوم      stem:  يوم
# word:  يَنْطُقُونَ      output:  ينطق      stem:  ينطقون
# word:  الْمُرَسِّلَاتُ      output:  مرسل      stem:  مرسلات
# word:  إشَارَةُ      output:  اشارة      stem:  اشارة
# word:  إِلَى      output:  ى      stem:  الى
# word:  الْقِيَامَةُ      output:  قيامة      stem:  قيامة
# word:  وَإِنَّ      output:  ان      stem:  ان
# word:  يَكِنَّ      output:  يكن      stem:  يكن
# word:  مَوْضُوعًا      output:  موض      stem:  موضوعا
# word:  حَاضِرًا      output:  حاضرا      stem:  حاضرا
# word:  لَلْإشَارَةُ      output:  اشارة      stem:  اشارة
# word:  إِلَى      output:  ى      stem:  الى
# word:  غَائِبُ      output:  غائب      stem:  غائب
# word:  قَالُ      output:  قال      stem:  قال
# word:  تَعَالَى      output:  تعالى      stem:  تعالى
# word:  آلِمُ      output:  م      stem:  الم
# word:  الْكُتَّابُ      output:  كتاب      stem:  كتاب
# word:  الْبَقَرَةُ      output:  قرة      stem:  بقرة
# word:  يُعَنِّي      output:  عن      stem:  يعني
# word:  وَكَقَوْلِ      output:  كقل      stem:  قول
# word:  خِفَافُ      output:  خفاف      stem:  خفاف
# word:  بُنُّ      output:  بن      stem:  بن
# word:  نَدْبَةُ      output:  ندبة      stem:  ندبة
# word:  السُّلَّمَيْ      output:  سلم      stem:  سلمي
# word:  فَإِنَّ      output:  فان      stem:  ان
# word:  تَكُّ      output:  تك      stem:  تك
# word:  أَصَبْتِ      output:  اصب      stem:  اصبت
# word:  حَمِيمُهَا      output:  حميم      stem:  حميم
# word:  فَعَمْدًا      output:  فعمدا      stem:  عمدا
# word:  تَيَمَّمْتِ      output:  يمم      stem:  تيممت
# word:  مَالِكًا      output:  مالكا      stem:  مالكا
# word:  أَقَوْلُ      output:  قول      stem:  قول
# word:  وَالرُّمْحُ      output:  رمح      stem:  رمح
# word:  يَأْطُرُ      output:  ياطر      stem:  ياطر
# word:  تَأَمُّلُ      output:  تامل      stem:  تامل
# word:  خِفَافًا      output:  خفافا      stem:  خفافا
# word:  إِنَّنِي      output:  انن      stem:  ان
# word:  أَنَّا      output:  انا      stem:  انا
# word:  يُعَنِّي      output:  عن      stem:  يعني
# word:  أَنَّا      output:  انا      stem:  انا
# word:  فَصْلُ      output:  فصل      stem:  فصل
# word:  يَبْدَأُ      output:  يبدا      stem:  يبدا
# word:  بِشَرْحِ      output:  شرح      stem:  شرح
# word:  التَّرْجَمَةُ      output:  ترجمة      stem:  ترجمة
# word:  فَيُقَوِّلُ      output:  فيقول      stem:  يقول
# word:  أَمًّا      output:  م      stem:  اما
# word:  قَوْلُهُ      output:  قول      stem:  قول
# word:  اخْتَصَرَتْ      output:  اخصر      stem:  اختصرت
# word:  فَحَدُّ      output:  فحد      stem:  حد
# word:  الْاخْتِصَارُ      output:  اختصار      stem:  اختصار
# word:  تَقْلِيلُ      output:  تقليل      stem:  تقليل
# word:  اللَّفْظُ      output:  لفظ      stem:  لفظ
# word:  اسْتِبْقَاءُ      output:  بقاا      stem:  استبقاا
# word:  الْمَعْنَى      output:  معنى      stem:  معنى
# word:  وَقَالُ      output:  قال      stem:  قال
# word:  الْخَلِيلُ      output:  خليل      stem:  خليل
# word:  بُنُّ      output:  بن      stem:  بن
# word:  أَحْمَد      output:  حمد      stem:  احمد
# word:  دَلُّ      output:  دل      stem:  دل
# word:  قَلِيلُهُ      output:  قليل      stem:  قليل
# word:  كَثِيرُهُ      output:  كثير      stem:  كثير
# word:  وَهْيُ      output:  هي      stem:  وهي
# word:  اخْتِصَارُ      output:  اختصار      stem:  اختصار
# word:  الْاجْتِمَاعَةُ      output:  اجتماعة      stem:  اجتماعة
# word:  سَمَّيْتَ      output:  سمي      stem:  سميت
# word:  الْمُخْتَصِرَةُ      output:  مختصرة      stem:  مختصرة
# word:  لَاجْتِمَاعُ      output:  اجتماع      stem:  اجتماع
# word:  السُّورُ      output:  سور      stem:  سور
# word:  وَسَمِيُّ      output:  سمي      stem:  سمي
# word:  خَصْرُ      output:  خصر      stem:  خصر
# word:  الْإنْسَانُ      output:  س      stem:  انسان
# word:  لَاجْتِمَاعُهُ      output:  اجتماع      stem:  اجتماع
# word:  وَمَنُّهُ      output:  منه      stem:  من
# word:  قَوْلُ      output:  قول      stem:  قول
# word:  عَمْرُ      output:  عمر      stem:  عمر
# word:  بُنُّ      output:  بن      stem:  بن
# word:  أبِّي      output:  ابي      stem:  اب
# word:  رَبِيعَة      output:  ربيعة      stem:  ربيعة
# word:  رَأَّتْ      output:  رات      stem:  رات
# word:  رَجْلًا      output:  رجلا      stem:  رجلا
# word:  أَمًّا      output:  م      stem:  اما
# word:  إِذًا      output:  ذ      stem:  اذا
# word:  الشَّمْسُ      output:  شمس      stem:  شمس
# word:  عَارَضْتِ      output:  عارض      stem:  عارضت
# word:  فَيَضْحَى      output:  فيضحى      stem:  يضحى
# word:  وَأَمًّا      output:  م      stem:  اما
# word:  بِالْعَشِيِّ      output:  عشي      stem:  عشي
# word:  فَيَخْصَرُ      output:  فيخصر      stem:  يخصر
# word:  مُعَنَّى      output:  معنى      stem:  معنى
# word:  أَنْهُ      output:  انه      stem:  انه
# word:  مُجْتَمَعُ      output:  مجتمع      stem:  مجتمع
# word:  شَدَّةُ      output:  شدة      stem:  شدة
# word:  الْبَرْدُ      output:  برد      stem:  برد
# word:  وَأَمًّا      output:  م      stem:  اما
# word:  فَهِّي      output:  فهي      stem:  فه
# word:  كَلِمَةُ      output:  كلمة      stem:  كلمة
# word:  إشَارَةُ      output:  اشارة      stem:  اشارة
# word:  تَجَمُّعُ      output:  تجمع      stem:  تجمع
# word:  حَرْفًا      output:  حرفا      stem:  حرفا
# word:  وَاسِمًا      output:  اسما      stem:  واسما
# word:  فَالْحَرْفُ      output:  حرف      stem:  حرف
# word:  الْمَوْضُوعَةُ      output:  موضوعة      stem:  موضوعة
# word:  لَلتَّنْبِيهُ      output:  تنبي      stem:  تنبيه
# word:  الْأَسْمَاءُ      output:  اسماا      stem:  اسماا
# word:  الْمُبَهِّمَةُ      output:  مبهمة      stem:  مبهمة
# word:  وَلَأجْلُ      output:  جل      stem:  اجل
# word:  حُسْنُ      output:  حسن      stem:  حسن
# word:  أَنُّ      output:  ان      stem:  ان
# word:  يَفْصُلُ      output:  يفصل      stem:  يفصل
# word:  بَيِّنُهُمَا      output:  بين      stem:  بين
# word:  فَنُقَوِّلُ      output:  قول      stem:  نقول
# word:  فَإِنَّ      output:  فان      stem:  ان
# word:  قِيلُ      output:  قيل      stem:  قيل
# word:  فَلَمُّ      output:  فلم      stem:  لم
# word:  اخْتَصَرَ      output:  اختصر      stem:  اختصر
# word:  كُتَّابُهُ      output:  كتاب      stem:  كتاب
# word:  وَهَلاَ      output:  هلا      stem:  هلا
# word:  بُسُطُهُ      output:  بسط      stem:  بسط
# word:  الْمَبْسُوطُ      output:  مبسوط      stem:  مبسوط
# word:  أَقُرَبُ      output:  اقرب      stem:  قرب
# word:  إِلَى      output:  ى      stem:  الى
# word:  الْأَفْهَامُ      output:  هام      stem:  افهام
# word:  وَأَغْنَى      output:  اغنى      stem:  اغنى
# word:  الشَّرْحُ      output:  شرح      stem:  شرح
# word:  قِيلُ      output:  قيل      stem:  قيل
# word:  إِنَّمَا      output:  انما      stem:  انما
# word:  اخْتَصَرَهُ      output:  اختصر      stem:  اختصر
# word:  لَأَنُّ      output:  ان      stem:  ان
# word:  الْمُخْتَصَرُ      output:  مختصر      stem:  مختصر
# word:  أَقُرَبُ      output:  اقرب      stem:  قرب
# word:  إِلَى      output:  ى      stem:  الى
# word:  الْحِفْظُ      output:  حفظ      stem:  حفظ
# word:  وَأَبْسَطَ      output:  ابسط      stem:  ابسط
# word:  لَلْقَارِئُ      output:  قارئ      stem:  قارئ
# word:  وَأحْسَن      output:  حسن      stem:  احسن
# word:  مَوْقِعًا      output:  موقعا      stem:  موقعا
# word:  النُّفُوسُ      output:  نفوس      stem:  نفوس
# word:  وَلَذُلُّكَ      output:  ذلك      stem:  ذل
# word:  تَدَاوُلُ      output:  تداول      stem:  تداول
# word:  إعْجَاز      output:  اعجاز      stem:  اعجاز
# word:  قَوْلُهُ      output:  قول      stem:  قول
# word:  عِزّ      output:  عز      stem:  عز
# word:  وَجْلُ      output:  جل      stem:  وجل
# word:  وَلَكَمُّ      output:  كم      stem:  كم
# word:  الْقُصَّاصُ      output:  قصاص      stem:  قصاص
# word:  حَيْوَة      output:  حيوة      stem:  حيوة
# word:  الْبَقَرَةُ      output:  قرة      stem:  بقرة
# word:  لَاخْتِصَارُ      output:  اختصار      stem:  اختصار
# word:  لَفْظُهُ      output:  لفظ      stem:  لفظ
# word:  وَإِجْمَاعُ      output:  اجماع      stem:  اجماع

# %%
print("Accuracy",true/len(words),"on ",len(words),"words.")
# Out:
# Accuracy 0.5240128068303095 on  937 words.
